# %%
import pandas as pd

# %%
df = pd.read_csv('anilist_anime_data_complete.csv')

# %%
df
# Out:
#        Unnamed: 0      id   idMal                  title_romaji  \
# 0               0    1497  1497.0  Aru Machi Kado no Monogatari
# 1               1    1547  1547.0              Obake no Q-tarou
# 2               2    1572  1572.0                 Jungle Taitei
# 3               3    1982  1982.0                           Osu
# 4               4    1984  1984.0                        Memory
# ...           ...     ...     ...                           ...
# 20211       20211  205842     NaN                             I
# 20212       20212  205843     NaN                    Heya Nikki
# 20213       20213  205844     NaN                Glass and Kumo
# 20214       20214  205858     NaN      Tententengoku Jigokugoku
# 20215       20215  205861     NaN                     Sanctuary
#
#                     title_english    title_native  \
# 0      Tales of the Street Corner         ある街角の物語
# 1                             NaN    オバQ; オバケのＱ太郎
# 2            Kimba the White Lion         ジャングル大帝
# 3                            Male              おす
# 4                             NaN            めもりい
# ...                           ...             ...
# 20211                         NaN               I
# 20212                         NaN            部屋日記
# 20213                         NaN  Glass and Kumo
# 20214                         NaN         天天天国地獄国
# 20215                   Sanctuary       Sanctuary
#
#                 title_userPreferred   type format    status  ...  \
# 0      Aru Machi Kado no Monogatari  ANIME  MOVIE  FINISHED  ...
# 1                  Obake no Q-tarou  ANIME     TV  FINISHED  ...
# 2                     Jungle Taitei  ANIME     TV  FINISHED  ...
# 3                               Osu  ANIME  MOVIE  FINISHED  ...
# 4                            Memory  ANIME  MOVIE  FINISHED  ...
# ...                             ...    ...    ...       ...  ...
# 20211                             I  ANIME  MOVIE  FINISHED  ...
# 20212                    Heya Nikki  ANIME  MOVIE  FINISHED  ...
# 20213                Glass and Kumo  ANIME  MOVIE  FINISHED  ...
# 20214      Tententengoku Jigokugoku  ANIME  MUSIC  FINISHED  ...
# 20215                     Sanctuary  ANIME  MUSIC  FINISHED  ...
#
#                                                relations  \
# 0                                                     []
# 1      [{"id": 2488, "relationType": "SEQUEL", "node"...
# 2      [{"id": 2552, "relationType": "ADAPTATION", "n...
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 20211                                                 []
# 20212                                                 []
# 20213                                                 []
# 20214                                                 []
# 20215                                                 []
#
#                                               characters  \
# 0      [{"id": 450688, "role": "BACKGROUND", "name": ...
# 1      [{"id": 359338, "role": "MAIN", "name": null, ...
# 2      [{"id": 61911, "role": "MAIN", "name": null, "...
# 3      [{"id": 217202, "role": "MAIN", "name": null, ...
# 4                                                     []
# ...                                                  ...
# 20211                                                 []
# 20212                                                 []
# 20213                                                 []
# 20214                                                 []
# 20215                                                 []
#
#                                                    staff  \
# 0      [{"id": 325739, "role": "Script Composition", ...
# 1      [{"id": 5749, "role": "Original Creator", "nod...
# 2      [{"id": 724627, "role": "ADR Director (Brazili...
# 3      [{"id": 3572, "role": "Director", "node": {"id...
# 4      [{"id": 3562, "role": "Director", "node": {"id...
# ...                                                  ...
# 20211  [{"id": 950545, "role": "Director", "node": {"...
# 20212  [{"id": 950546, "role": "Director", "node": {"...
# 20213  [{"id": 950547, "role": "Director", "node": {"...
# 20214  [{"id": 950748, "role": "Photography", "node":...
# 20215  [{"id": 950758, "role": "Music Lyrics", "node"...
#
#                                                  studios  nextAiringEpisode  \
# 0      [{"id": 3736, "isMain": false, "node": {"id": ...                NaN
# 1      [{"id": 3849, "isMain": false, "node": {"id": ...                NaN
# 2      [{"id": 3921, "isMain": true, "node": {"id": 6...                NaN
# 3      [{"id": 4672, "isMain": false, "node": {"id": ...                NaN
# 4      [{"id": 4675, "isMain": false, "node": {"id": ...                NaN
# ...                                                  ...                ...
# 20211  [{"id": 46112, "isMain": false, "node": {"id":...                NaN
# 20212  [{"id": 46113, "isMain": false, "node": {"id":...                NaN
# 20213  [{"id": 46114, "isMain": false, "node": {"id":...                NaN
# 20214                                                 []                NaN
# 20215                                                 []                NaN
#
#        airingSchedule                                    recommendations  \
# 0                  []  [{"node": {"id": 223736, "rating": 2, "mediaRe...
# 1                  []  [{"node": {"id": 104978, "rating": 2, "mediaRe...
# 2                  []  [{"node": {"id": 190947, "rating": 1, "mediaRe...
# 3                  []  [{"node": {"id": 322324, "rating": 3, "mediaRe...
# 4                  []                                                 []
# ...               ...                                                ...
# 20211              []                                                 []
# 20212              []                                                 []
# 20213              []                                                 []
# 20214              []                                                 []
# 20215              []                                                 []
#
#                                                  reviews  \
# 0                                                     []
# 1                                                     []
# 2      [{"node": {"id": 27621, "summary": "A repetiti...
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 20211                                                 []
# 20212                                                 []
# 20213                                                 []
# 20214                                                 []
# 20215                                                 []
#
#                                  stats_scoreDistribution  \
# 0      [{"score": 10, "amount": 12}, {"score": 20, "a...
# 1      [{"score": 10, "amount": 13}, {"score": 20, "a...
# 2      [{"score": 10, "amount": 10}, {"score": 20, "a...
# 3      [{"score": 10, "amount": 66}, {"score": 20, "a...
# 4      [{"score": 10, "amount": 31}, {"score": 20, "a...
# ...                                                  ...
# 20211                                                NaN
# 20212                                                NaN
# 20213                                                NaN
# 20214                                                NaN
# 20215                                                NaN
#
#                                 stats_statusDistribution
# 0      [{"status": "CURRENT", "amount": 27}, {"status...
# 1      [{"status": "CURRENT", "amount": 20}, {"status...
# 2      [{"status": "CURRENT", "amount": 109}, {"statu...
# 3      [{"status": "CURRENT", "amount": 8}, {"status"...
# 4      [{"status": "CURRENT", "amount": 8}, {"status"...
# ...                                                  ...
# 20211                                                NaN
# 20212                                                NaN
# 20213                                                NaN
# 20214                                                NaN
# 20215                                                NaN
#
# [20216 rows x 62 columns]

# %% [markdown]
# Data Preprocessing and Basic EDA

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'idMal', 'title_romaji', 'title_english',
#        'title_native', 'title_userPreferred', 'type', 'format', 'status',
#        'description', 'startDate_year', 'startDate_month', 'startDate_day',
#        'endDate_year', 'endDate_month', 'endDate_day', 'season', 'seasonYear',
#        'seasonInt', 'episodes', 'duration', 'chapters', 'volumes',
#        'countryOfOrigin', 'isLicensed', 'source', 'hashtag', 'trailer_id',
#        'trailer_site', 'trailer_thumbnail', 'updatedAt',
#        'coverImage_extraLarge', 'coverImage_large', 'coverImage_medium',
#        'coverImage_color', 'bannerImage', 'genres', 'synonyms', 'tags',
#        'averageScore', 'meanScore', 'popularity', 'favourites', 'trending',
#        'rankings', 'isFavourite', 'isAdult', 'isLocked', 'siteUrl',
#        'externalLinks', 'streamingEpisodes', 'relations', 'characters',
#        'staff', 'studios', 'nextAiringEpisode', 'airingSchedule',
#        'recommendations', 'reviews', 'stats_scoreDistribution',
#        'stats_statusDistribution'],
#       dtype='object')

# %%
df['season']
# Out:
# 0          FALL
# 1        SUMMER
# 2          FALL
# 3          FALL
# 4          FALL
#           ...
# 20211       NaN
# 20212       NaN
# 20213       NaN
# 20214       NaN
# 20215       NaN
# Name: season, Length: 20216, dtype: object

# %%
print(df['tags'].sample(10))
# Out:
# 2378                                                    []
# 18893    [{"id": 89, "name": "Full CGI", "description":...
# 15403    [{"id": 281, "name": "Surreal Comedy", "descri...
# 17134    [{"id": 244, "name": "Isekai", "description": ...
# 12662    [{"id": 433, "name": "Animals", "description":...
# 6594     [{"id": 29, "name": "Magic", "description": "P...
# 3564     [{"id": 56, "name": "Shounen", "description": ...
# 3590     [{"id": 29, "name": "Magic", "description": "P...
# 9033     [{"id": 433, "name": "Animals", "description":...
# 1267     [{"id": 63, "name": "Space", "description": "P...
# Name: tags, dtype: object

# %%
req_col = ['id', 'title_english', 'title_romaji', 'genres', 'averageScore', 'format', 'popularity']

# %%
df = df[req_col]

# %%
df
# Out:
#            id               title_english                  title_romaji  \
# 0        1497  Tales of the Street Corner  Aru Machi Kado no Monogatari
# 1        1547                         NaN              Obake no Q-tarou
# 2        1572        Kimba the White Lion                 Jungle Taitei
# 3        1982                        Male                           Osu
# 4        1984                         NaN                        Memory
# ...       ...                         ...                           ...
# 20211  205842                         NaN                             I
# 20212  205843                         NaN                    Heya Nikki
# 20213  205844                         NaN                Glass and Kumo
# 20214  205858                         NaN      Tententengoku Jigokugoku
# 20215  205861                   Sanctuary                     Sanctuary
#
#                                          genres  averageScore format  \
# 0      ["Drama", "Fantasy", "Music", "Romance"]          62.0  MOVIE
# 1                                    ["Comedy"]          57.0     TV
# 2                                 ["Adventure"]          61.0     TV
# 3                             ["Slice of Life"]          46.0  MOVIE
# 4                                   ["Mystery"]          54.0  MOVIE
# ...                                         ...           ...    ...
# 20211                                        []           NaN  MOVIE
# 20212                                        []           NaN  MOVIE
# 20213                                        []           NaN  MOVIE
# 20214                                        []           NaN  MUSIC
# 20215                                        []           NaN  MUSIC
#
#        popularity
# 0            2068
# 1             414
# 2            2479
# 3            1325
# 4            1163
# ...           ...
# 20211           0
# 20212           0
# 20213           0
# 20214           0
# 20215           0
#
# [20216 rows x 7 columns]

# %%
df.dropna(inplace=True)
# Out:
# C:\Users\Nikhil Sharma\AppData\Local\Temp\ipykernel_18932\1379821321.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)

# %%
df
# Out:
#            id                                      title_english  \
# 0        1497                         Tales of the Street Corner
# 2        1572                               Kimba the White Lion
# 3        1982                                               Male
# 5        1989                                           The Drop
# 6        2047                                            Mermaid
# ...       ...                                                ...
# 20161  201262                                    POKÉTOON (2025)
# 20163  201961                                      Quiet Please!
# 20172  204066  JUJUTSU KAISEN: Execution -Shibuya Incident x ...
# 20193  204654                       August, A Certain, Moonlight
# 20196  204732                                     Latest Episode
#
#                                             title_romaji  \
# 0                           Aru Machi Kado no Monogatari
# 2                                          Jungle Taitei
# 3                                                    Osu
# 5                                                Shizuku
# 6                                                 Ningyo
# ...                                                  ...
# 20161                                    POKÉTOON (2025)
# 20163                            Jebal Joyonghi Jom Hae!
# 20172  Jujutsu Kaisen: Shibuya Jihen Tokubetsu Henshu...
# 20193                        Hachigatsu, Bou, Tsukiakari
# 20196                                          Saishinwa
#
#                                          genres  averageScore format  \
# 0      ["Drama", "Fantasy", "Music", "Romance"]          62.0  MOVIE
# 2                                 ["Adventure"]          61.0     TV
# 3                             ["Slice of Life"]          46.0  MOVIE
# 5                                    ["Comedy"]          50.0  MOVIE
# 6                                   ["Fantasy"]          57.0  MOVIE
# ...                                         ...           ...    ...
# 20161    ["Comedy", "Fantasy", "Slice of Life"]          59.0    ONA
# 20163                     ["Comedy", "Romance"]          71.0    ONA
# 20172       ["Action", "Drama", "Supernatural"]          75.0  MOVIE
# 20193                         ["Psychological"]          57.0  MUSIC
# 20196                               ["Romance"]          58.0  MUSIC
#
#        popularity
# 0            2068
# 2            2479
# 3            1325
# 5            1009
# 6            1495
# ...           ...
# 20161         502
# 20163         907
# 20172        6629
# 20193         255
# 20196         198
#
# [8816 rows x 7 columns]

# %%
df = df.drop_duplicates(subset=['id'])

# %%
df['genres'] = df['genres'].astype(str)

# %%
df
# Out:
#           id                                      title_english  \
# 0       1497                         Tales of the Street Corner
# 1       1572                               Kimba the White Lion
# 2       1982                                               Male
# 3       1989                                           The Drop
# 4       2047                                            Mermaid
# ...      ...                                                ...
# 8811  201262                                    POKÉTOON (2025)
# 8812  201961                                      Quiet Please!
# 8813  204066  JUJUTSU KAISEN: Execution -Shibuya Incident x ...
# 8814  204654                       August, A Certain, Moonlight
# 8815  204732                                     Latest Episode
#
#                                            title_romaji  \
# 0                          Aru Machi Kado no Monogatari
# 1                                         Jungle Taitei
# 2                                                   Osu
# 3                                               Shizuku
# 4                                                Ningyo
# ...                                                 ...
# 8811                                    POKÉTOON (2025)
# 8812                            Jebal Joyonghi Jom Hae!
# 8813  Jujutsu Kaisen: Shibuya Jihen Tokubetsu Henshu...
# 8814                        Hachigatsu, Bou, Tsukiakari
# 8815                                          Saishinwa
#
#                                         genres  averageScore format  \
# 0     ["Drama", "Fantasy", "Music", "Romance"]          62.0  MOVIE
# 1                                ["Adventure"]          61.0     TV
# 2                            ["Slice of Life"]          46.0  MOVIE
# 3                                   ["Comedy"]          50.0  MOVIE
# 4                                  ["Fantasy"]          57.0  MOVIE
# ...                                        ...           ...    ...
# 8811    ["Comedy", "Fantasy", "Slice of Life"]          59.0    ONA
# 8812                     ["Comedy", "Romance"]          71.0    ONA
# 8813       ["Action", "Drama", "Supernatural"]          75.0  MOVIE
# 8814                         ["Psychological"]          57.0  MUSIC
# 8815                               ["Romance"]          58.0  MUSIC
#
#       popularity
# 0           2068
# 1           2479
# 2           1325
# 3           1009
# 4           1495
# ...          ...
# 8811         502
# 8812         907
# 8813        6629
# 8814         255
# 8815         198
#
# [8816 rows x 7 columns]

# %%
from collections import Counter
all_genres = Counter(",".join(df['genres']).split(','))
print(all_genres.most_common(10))
# Out:
# [('["Action"', 2900), ('["Comedy"', 1757), (' "Sci-Fi"]', 1480), (' "Drama"', 1180), (' "Comedy"', 1114), (' "Supernatural"]', 1102), (' "Slice of Life"]', 1093), (' "Fantasy"', 1073), (' "Adventure"', 1056), (' "Fantasy"]', 939)]

# %%
df['averageScore'].hist()
# Out:
# <Axes: >

# %%
df.sort_values('popularity', ascending=False)[['title_english','popularity']].head()
# Out:
#                        title_english  popularity
# 4071                 Attack on Titan      938026
# 6197  Demon Slayer: Kimetsu no Yaiba      890351
# 2634                      Death Note      854079
# 6620                  JUJUTSU KAISEN      847691
# 5074                My Hero Academia      789122

# %%
import matplotlib.pyplot as plt

# 1. Top 10 Genres
top_genres = dict(all_genres.most_common(10))
plt.bar(top_genres.keys(), top_genres.values())
plt.xticks(rotation=45)
plt.title("Top 10 Genres")
plt.show()

# 2. Average Score by Format
df.groupby('format')['averageScore'].mean().plot(kind='bar')
plt.title("Average Score by Format")
plt.show()

# 3. Popularity vs Score
plt.scatter(df['popularity'], df['averageScore'])
plt.title("Popularity vs Average Score")
plt.xlabel("Popularity")
plt.ylabel("Average Score")
plt.show()

# %% [markdown]
# Modeling

# %%
df['genres'] = df['genres'].apply(lambda x: " ".join(eval(x)))

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer()
genre_matrix = tfidf.fit_transform(df['genres'])

# %%
print(genre_matrix.shape)
# Out:
# (8816, 23)

# %%
print(genre_matrix)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 28383 stored elements and shape (8816, 23)>
#   Coords	Values
#   (0, 3)	0.4080824952758784
#   (0, 5)	0.3916006169840829
#   (0, 12)	0.6928567870517804
#   (0, 16)	0.4472886165144182
#   (1, 1)	1.0
#   (2, 19)	0.5773502691896257
#   (2, 14)	0.5773502691896257
#   (2, 9)	0.5773502691896257
#   (3, 2)	1.0
#   (4, 5)	1.0
#   (5, 1)	0.4363597912084494
#   (5, 11)	0.6250504436417497
#   (5, 17)	0.4576582106330937
#   (5, 6)	0.4576582106330937
#   (6, 3)	0.37496980819045345
#   (6, 1)	0.37958517941361725
#   (6, 11)	0.5437253605224487
#   (6, 17)	0.398112469327614
#   (6, 6)	0.398112469327614
#   (6, 0)	0.3204502931370464
#   (7, 0)	1.0
#   (8, 5)	0.46823594434990123
#   (8, 1)	0.4939492097503325
#   (8, 17)	0.518058528839058
#   (8, 6)	0.518058528839058
#   :	:
#   (8807, 19)	0.5351432495961498
#   (8807, 14)	0.5351432495961498
#   (8807, 9)	0.5351432495961498
#   (8807, 2)	0.37532000644119523
#   (8808, 5)	0.7641521277566278
#   (8808, 2)	0.6450360653831833
#   (8809, 2)	0.6879251414743025
#   (8809, 0)	0.7257816474171559
#   (8810, 16)	0.4528095848889228
#   (8810, 19)	0.4771375986016897
#   (8810, 14)	0.4771375986016897
#   (8810, 9)	0.4771375986016897
#   (8810, 2)	0.3346380370408601
#   (8811, 5)	0.4062790938907591
#   (8811, 19)	0.4889866275842688
#   (8811, 14)	0.4889866275842688
#   (8811, 9)	0.4889866275842688
#   (8811, 2)	0.3429482934767202
#   (8812, 16)	0.8042163018926205
#   (8812, 2)	0.5943367225488911
#   (8813, 3)	0.5540769645636997
#   (8813, 0)	0.47351579203608773
#   (8813, 21)	0.6846762096292768
#   (8814, 15)	1.0
#   (8815, 16)	1.0

# %%
from sklearn.metrics.pairwise import cosine_similarity

cosine_sim = cosine_similarity(genre_matrix, genre_matrix)

# %%
df['title'] = df['title_english'].fillna(df['title_romaji'])

indices = pd.Series(df.index, index=df['title'].str.lower()).drop_duplicates()

# %%
def recommend(title, top_n=5):
    title = title.lower()
    
    matches = df[df['title'].str.lower().str.contains(title)]
    
    if matches.empty:
        return "Anime not found in dataset"
    
    idx = matches.index[0]
    
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)[1:top_n+1]
    
    anime_indices = [i[0] for i in sim_scores]
    
    result = df[['title','genres','averageScore','format']].iloc[anime_indices]
    
    # sort recommendations by rating (descending)
    result = result.sort_values(by='averageScore', ascending=False)
    
    return result

# %%
recommend("jujutsu kaisen")
# Out:
#                                                   title  \
# 3897                       HAKUOKI: WILD DANCE OF TOKYO
# 3503  Hakuoki ~Demon of the Fleeting Blossom~ Record...
# 3896  Hakuoki ~Demon of the Fleeting Blossom~ Dawn o...
# 3377            Hakuoki ~Demon of the Fleeting Blossom~
# 2847                  Ghost Slayers Ayashi: Inferno OVA
#
#                          genres  averageScore format
# 3897  Action Drama Supernatural          72.0  MOVIE
# 3503  Action Drama Supernatural          71.0     TV
# 3896  Action Drama Supernatural          69.0     TV
# 3377  Action Drama Supernatural          68.0     TV
# 2847  Action Drama Supernatural          58.0    OVA

# %%
import pickle

# Save cosine similarity matrix
pickle.dump(cosine_sim, open("cosine_sim.pkl", "wb"))

# Save cleaned dataframe
df.to_csv("cleaned_anime.csv", index=False)

print("Files saved successfully!")
# Out:
# Files saved successfully!
